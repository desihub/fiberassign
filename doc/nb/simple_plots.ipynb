# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.table import Table
import fitsio
# %matplotlib inline

# %%
tilefile = '/global/cscratch1/sd/forero/small_dr7.1/output_fiberassign/tile_17855.fits'
targets_data = fitsio.read(tilefile, ext=1)
potential_data = fitsio.read(tilefile, ext=2)
sky_data = fitsio.read(tilefile, ext=3)
gfa_data = fitsio.read(tilefile, ext=4)

plt.scatter(targets_data['RA'], targets_data['DEC'], color='BLUE', s=1.0)
plt.scatter(gfa_data['RA'], gfa_data['DEC'], color='RED', s=2.0)
plt.scatter(sky_data['RA'], sky_data['DEC'], color='black', s=20.0)

# %%
Table(targets_data[:1])
# Out:
# <Table length=1>
# FIBER LOCATION NUMTARGET PRIORITY ... FLUX_IVAR_W2   RA_IVAR     DEC_IVAR
# int32  int32     int16    int32   ...   float32      float32     float32
# ----- -------- --------- -------- ... ------------ ----------- -----------
#    97      526        12     3000 ...     0.540948 8.30824e+10 8.81975e+10

# %%
# Out:
# /global/u2/f/forero/fiberassign/bin
